# %%
# %run -i CouplingsModel_1.py
import matplotlib.pyplot as plt
# direc = '/home/as974/ada'
direc = '/Users/adashaw/Dropbox (Harvard University)/Debbie-Ada'

# %%
correctedModel = CouplingsModel_1(direc+'/repeatsProject/PF00023/cOutput/PF00023_heni.model')

# %%
plt.imshow(correctedModel.cn_scores)
# Out:
# CouplingsModel_1.py:749: RuntimeWarning: invalid value encountered in true_divide
#   ) / matrix_mean

# %%
uncorrectedModel = CouplingsModel_1(direc+'/repeatsProject/PF00023/cOutput/PF00023_no_correction.model')

# %%
plt.imshow(uncorrectedModel.cn_scores);
# Out:
# CouplingsModel_1.py:749: RuntimeWarning: invalid value encountered in true_divide
#   ) / matrix_mean

# %%
def plot_top_n(z,n):
    z[z<np.sort(z.flatten())[::-1][n-1]] = 0
    plt.imshow(z)

# %%
plot_top_n(uncorrectedModel.cn_scores,150)

# %%
plot_top_n(correctedModel.cn_scores,150)
